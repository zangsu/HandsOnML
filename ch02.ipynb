# %%
#프로젝트를 위한 초기 설정을 합니다.
#라이브러리를 import 합니다.
import sys
assert sys.version_info >= (3, 5)

import sklearn
assert sklearn.__version__ >= "0.20"

import numpy as np
import os

# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize = 14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

#그래프를 저장 할 위치 지정
PROJECT_ROOT_DIR = "."
CHAPTER_ID = "end_to_end_project"
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID)
os.makedirs(IMAGES_PATH, exist_ok = True)

def save_fig(fig_id, tight_layout = True, fig_extension="png", resolution = 300):
  path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
  print("그림 저장:", fig_id)
  if tight_layout : 
    plt.tight_layout()
  plt.savefig(path, format=fig_extension, dpi=resolution)

# %%
#데이터 다운로드 하기
import tarfile
import os
import urllib.request

DOWNLOAD_ROOT = "https://raw.githubusercontent.com/rickiepark/handson-ml2/master/"
HOUSING_PATH = os.path.join("datasets", "housing")
HOUSING_URL = DOWNLOAD_ROOT + "datasets/housing/housing.tgz"

def fetch_housing_data(housing_url = HOUSING_URL, housing_path= HOUSING_PATH):
  if not os.path.isdir(housing_path):
    os.makedirs(housing_path)
  tgz_path = os.path.join(housing_path, "housing.tgz")
  urllib.request.urlretrieve(housing_url, tgz_path)
  housing_tgz = tarfile.open(tgz_path)
  housing_tgz.extractall(path=housing_path)
  housing_tgz.close()

# %%
fetch_housing_data()

# %%
import pandas as pd #csv 파일을 처리하기 위해 import 하는 것으로 보임

#housing csc파일을 읽어오는 함수
def load_housing_data(housing_path = HOUSING_PATH):
  csv_path = os.path.join(housing_path, "housing.csv")
  return pd.read_csv(csv_path)

# %%
#데이터 구조 훑어보기
housing = load_housing_data()
housing.head() #데이터 미리보기 - 기본 5개, 더 보고싶으면 괄호안에 보고싶은 개수
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
housing["ocean_proximity"].value_counts() #ocean_proximity에 들어가는 값들을 값별로 카운트
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %%
housing.describe() #기본적인 정보들(숫자, 중간값, 25퍼센트에 해당하는 값 등등)- 숫자들로 이루어진 값만 나오는듯? ocean_proximity는 안나오네
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
# %matplotlib inline 
#그래프를 코드환경 안에서 보겠다.
import matplotlib.pyplot as plt
housing.hist(bins = 50, figsize = (20,15)) #bins = 얼마나 촘촘하게 그래프를 표시할건가. figsize() = 그래프 크기
save_fig("attribute_histogram_plots")
plt.show()
# Out:
# 그림 저장: attribute_histogram_plots

# %%
#랜덤 시드값 설정
np.random.seed(42)

# %%
import numpy as np

# 실전에서는 사이킷런 train_feat_split
def split_train_test(data, test_ratio):
  shuffled_indices = np.random.permutation(len(data))
  test_set_size = int(len(data) * test_ratio)
  test_indices = shuffled_indices[:test_set_size]
  train_indices = shuffled_indices[test_set_size:]
  return data.iloc[train_indices], data.iloc[test_indices]

# 원본 데이터 자체를 섞는게 아니라, 순서가 무작위인 인덱스번호 배열을 통해 훈련/테스트 데이터 구분

# %%
train_set, test_set = split_train_test(housing, 0.2) #test_set의 크기를 전체의 20퍼센트로 가져가겠다.
len(train_set)
# Out:
# 16512

# %%
len(test_set)
# Out:
# 4128

# %%
from zlib import crc32
#crc32는 원본데이터와 대상데이터 사이의 변경내용을 탐지하는 오류감지함수

def test_set_check(identifier, test_ratio):
  return crc32(np.int64(identifier)) & 0xffffffff < test_ratio * 2**32

def split_train_test_by_id(data, test_ratio, id_column):
  ids = data[id_column]
  in_test_set = ids.apply(lambda id_: test_set_check(id_ ,test_ratio))
  return data.loc[~in_test_set], data.loc[in_test_set]

  #일단 이해는 잘 안되지만, 아래 사용 사례를 보면서 다시 이해해보기

# %%
housing_with_id = housing.reset_index() # 그냥 index열만 하나 더 넣어준 거
train_set, test_set = split_train_test_by_id(housing_with_id, 0.2, "index")

# %%
#식별자를 위도와 경도를 이용해 만듦 (위도와 경도는 정밀도가 낮아 여러 구역의 ID가 동일해 진다.)

housing_with_id["id"] = housing["longitude"] * 1000 + housing["latitude"]
train_set, test_set = split_train_test_by_id(housing_with_id, 0.2, "id")

# %%
test_set.head()
# Out:
#     index  longitude  latitude  housing_median_age  total_rooms  \
# 59     59    -122.29     37.82                 2.0        158.0
# 60     60    -122.29     37.83                52.0       1121.0
# 61     61    -122.29     37.82                49.0        135.0
# 62     62    -122.29     37.81                50.0        760.0
# 67     67    -122.29     37.80                52.0       1027.0
#
#     total_bedrooms  population  households  median_income  median_house_value  \
# 59            43.0        94.0        57.0         2.5625             60000.0
# 60           211.0       554.0       187.0         3.3929             75700.0
# 61            29.0        86.0        23.0         6.1183             75000.0
# 62           190.0       377.0       122.0         0.9011             86100.0
# 67           244.0       492.0       147.0         2.6094             81300.0
#
#    ocean_proximity         id
# 59        NEAR BAY -122252.18
# 60        NEAR BAY -122252.17
# ...

# %%
from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split(housing, test_size = 0.2, random_state = 42)

# %%
test_set.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20046    -119.01     36.06                25.0       1505.0             NaN
# 3024     -119.46     35.14                30.0       2943.0             NaN
# 15663    -122.44     37.80                52.0       3830.0             NaN
# 20484    -118.72     34.28                17.0       3051.0             NaN
# 9814     -121.93     36.62                34.0       2351.0             NaN
#
#        population  households  median_income  median_house_value  \
# 20046      1392.0       359.0         1.6812             47700.0
# 3024       1565.0       584.0         2.5313             45800.0
# 15663      1310.0       963.0         3.4801            500001.0
# 20484      1705.0       495.0         5.7376            218600.0
# 9814       1063.0       428.0         3.7250            278000.0
#
#       ocean_proximity
# 20046          INLAND
# 3024           INLAND
# 15663        NEAR BAY
# 20484       <1H OCEAN
# ...

# %%
housing["median_income"].hist()

# %%
housing["income_cat"] = pd.cut(housing["median_income"], bins = [0., 1.5, 3.0, 4.5, 6., np.inf], labels = [1,2,3,4,5])
# pd.cut -> 카테고리 그룹을 만들어 준다. 중간 소득이 0~1.5 ($0 ~ $15,000) 이 카테고리 1이 된다.

# %%
housing["income_cat"].value_counts()
# Out:
# 3    7236
# 2    6581
# 4    3639
# 5    2362
# 1     822
# Name: income_cat, dtype: int64

# %%
housing["income_cat"].hist()

# %%
# 이제 앞에서 만든 소득카테고리를 통해 계층 샘플링을 하자.
from sklearn.model_selection import StratifiedShuffleSplit
split = StratifiedShuffleSplit(n_splits=1, test_size = 0.2, random_state = 42)
for train_index, test_index in split.split(housing, housing["income_cat"]):
  strat_train_set = housing.loc[train_index]
  strat_test_set = housing.loc[test_index]

  #pandas -> loc함수 : 해당 열, 행을 반환

# %%
strat_test_set["income_cat"].value_counts() / len(strat_test_set) #이건 계층 샘플링을 했을때 테스트세트에서의 각 카테고리 비율
# Out:
# 3    0.350533
# 2    0.318798
# 4    0.176357
# 5    0.114341
# 1    0.039971
# Name: income_cat, dtype: float64

# %%
housing["income_cat"].value_counts() / len(housing) #전체 데이터에서의 각 카테고리 비율 -> 계층 샘플링 한 테스트케이스와 거의 차이가 없다.
# Out:
# 3    0.350581
# 2    0.318847
# 4    0.176308
# 5    0.114438
# 1    0.039826
# Name: income_cat, dtype: float64

# %%
def income_cat_proportions(data):
  return data["income_cat"].value_counts() / len(data)

train_set, test_set = train_test_split(housing, test_size = 0.2, random_state = 42)

compare_props = pd.DataFrame({
    "Overall" : income_cat_proportions(housing),
    "Stratified" : income_cat_proportions(strat_test_set), 
    "Random": income_cat_proportions(test_set),
}).sort_index()
compare_props["Rand. %error"] = 100 * compare_props["Random"] / compare_props["Overall"] - 100
compare_props["Start. %error"] = 100 * compare_props["Stratified"] / compare_props["Overall"] - 100

# %%
compare_props
# Out:
#     Overall  Stratified    Random  Rand. %error  Start. %error
# 1  0.039826    0.039971  0.040213      0.973236       0.364964
# 2  0.318847    0.318798  0.324370      1.732260      -0.015195
# 3  0.350581    0.350533  0.358527      2.266446      -0.013820
# 4  0.176308    0.176357  0.167393     -5.056334       0.027480
# 5  0.114438    0.114341  0.109496     -4.318374      -0.084674

# %%
for set_ in  (strat_train_set, strat_test_set):
  set_.drop("income_cat", axis = 1, inplace = True)
  #income_cat 카테고리를 삭제

# %%
#데이터 이해를 위한 탐색과 시각화
housing = strat_train_set.copy()

# %%
housing.plot(kind = "scatter", x = "longitude", y = "latitude")
save_fig("bad_visualization_plot")
# Out:
# 그림 저장: bad_visualization_plot

# %%
housing.plot(kind="scatter", x = "longitude", y="latitude", alpha=0.1)
save_fig("better_visualization_plot")
#alpha point를 0.1로 설정하면서 어느 부분의 밀집도가 높은지 확인할 수 있게 되었다.
# Out:
# 그림 저장: better_visualization_plot

# %%
#조금 더 많은 정보를 보기 위해 원의 크기, 색을 인구 수와 주택 가격을 나타내도록 설정함
housing.plot(kind = "scatter", x="longitude", y="latitude", alpha=0.4,
             s=housing["population"]/100, label = "population", figsize=(10,7),
             c = "median_house_value", cmap=plt.get_cmap("jet"), colorbar=True,
             sharex=False)
plt.legend()
save_fig("housing_prices_scatterplot")
# Out:
# 그림 저장: housing_prices_scatterplot
